# %% [markdown]
# # IC 4.7. Deriving New Variables

# %% [markdown]
# ### 0. List of Contents
# #### 1. Importing Libraries and Dataframes
# #### 2. Creating Price Label with User-Defined Function
# #### 3. Creating Price Label with loc() Function
# #### 4. Creating Busiest Day Column with For-Loops
# #### 5. Creating Busiest and Slowes Days Column with For-Loops
# #### 6. Creating Busiest Periods with For-Loops
# #### 7. Exporting

# %% [markdown]
# ### 1. Importing Libraries and Dataframes

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating path
path = r'/Users/fruzsinasari/Documents/Fru Python/Instacart Basket Analysis/02 Data/'

# %%
# Importing df_ords_prods_merged
df_ords_prods_merge = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# ### 2. Creating Price Label with User-Defined Function

# %%
#creating subset
df = df_ords_prods_merged[:1000000]

# %%
#defining price_label function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#using price_label function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/rk/rxjz8lb163zdxm55x_n734800000gp/T/ipykernel_964/3739848536.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# checking frequency of new column
df['price_range'].value_counts()
# Out:
# Mid-range product    672525
# Low-range product    314109
# High range            12413
# Not enough data         953
# Name: price_range, dtype: int64

# %% [markdown]
# ### 3. Creating Price Label with loc() Function

# %%
#checking max
df['prices'].max()
# Out:
# 99999.0

# %%
# loc 1
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /Users/fruzsinasari/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/fruzsinasari/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# loc 2
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# loc 3
 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     672525
# Low-range product     314109
# High-range product     12413
# NaN                      953
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts()
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### 4. Creating Busiest Day Column with For-Loops

# %%
#checking frequency of orders daily
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6209808
# 1    5665951
# 6    4500391
# 2    4217868
# 5    4209603
# 3    3844175
# 4    3787263
# Name: orders_day_of_week, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['busiest_day']=result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22437988
# Busiest day        6209808
# Least busy         3787263
# Name: busiest_day, dtype: int64

# %% [markdown]
# ### 5. Creating Busiest and Slowes Days Column with For-Loops

# %%
new_result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    new_result.append("Busiest_days")
  elif value == 1:
    new_result.append("Busiest_days")
  elif value == 3:
    new_result.append("Slowest_days")
  elif value ==4:
    new_result.append("Slowest_days")
  else:
    new_result.append("Regularly busy")

# %%
#7.2 print result_new
new_result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
# ...

# %%
#7.2 Creating new column
df_ords_prods_merged['how busy']=new_result

# %%
df_ords_prods_merged['how busy'].value_counts()
# Out:
# Regularly busy    12927862
# Busiest_days      11875759
# Slowest_days       7631438
# Name: how busy, dtype: int64

# %% [markdown]
# #### the number of busiest and slowest days increased since now we have two days for both categories instead of one

# %% [markdown]
# ### 6. Creating Busiest Periods with For-Loops

# %%
#checking the frequency of the order hours
df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764476
# 11    2738647
# 14    2691598
# 15    2664583
# 13    2663346
# 12    2620898
# 16    2537506
# 9     2456751
# 17    2089510
# 8     1719991
# 18    1637956
# 19    1259416
# 20     977049
# 7      891951
# 21     796379
# 22     634743
# 23     402621
# 6      290796
# 0      218951
# 1      115787
# 5       88064
# 2       69435
# 4       53284
# 3       51321
# Name: order_hour_of_day, dtype: int64

# %%
period_result = []

for value in df_ords_prods_merge["order_hour_of_day"]:
  if value > 10 & value <=18:
    period_result.append("Most_orders")
  elif value <=5:
    period_result.append("Fewest_orders")
  else:
    period_result.append("Average_orders")

# %%
period_result
# Out:
# ['Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
# ...

# %%
#Create new column name titled 'busiest_period_of_day'
df_ords_prods_merge['Busiest_period_of_day'] = period_result

# %%
#Checking result
df_ords_prods_merge['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rk/rxjz8lb163zdxm55x_n734800000gp/T/ipykernel_1349/3828180867.py in <module>
#       1 #Checking result
# ----> 2 df_ords_prods_merge['Busiest_period_of_day'].value_counts(dropna = False)
#
# NameError: name 'df_ords_prods_merge' is not defined

# %% [markdown]
# ### 7. Exporting

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_with_flags.pkl'))
